# %%
import pandas as pd
import json
import numpy as np

# %%
js = pd.read_json('customers.json')
js
# Out:
#                                 comment  \
# 0  Export to JSON plugin for PHPMyAdmin
# 1                                   NaN
# 2                                   NaN
#
#                                                 data database       name  \
# 0                                                NaN      NaN        NaN
# 1                                                NaN      NaN     db_ktm
# 2  [{'id': '1', 'name': 'Manish Basnyat', 'image'...   db_ktm  customers
#
#        type version
# 0    header   4.8.2
# 1  database     NaN
# 2     table     NaN

# %%
d = pd.DataFrame(df['data'][2])
d
# Out:
#   address contact           created_at                       email  \
# 0    None    None  2018-11-20 07:31:17  manishbasnyat182@gmail.com
# 1    None    None  2018-11-20 07:31:18    seeder2sapkota@gmail.com
# 2    None    None  2018-11-20 07:31:18      seeder3singh@gmail.com
#
#   facebook_url gender google_url id image linkedin_url             name  \
# 0         None   None       None  1  None         None   Manish Basnyat
# 1         None   None       None  2  None         None  Seeder2 Sapkota
# 2         None   None       None  3  None         None    Seeder2 Singh
#
#                                             password  \
# 0  $2y$10$k6UbClXDSy6oYuxxzpWR6uG5lwPcLk9kv3CNyWE...
# 1  $2y$10$YXIRGFplgA4NGsEg5/F2Qu/GDIlUBZ9DVIU0pkg...
# 2  $2y$10$2cDsOcjx5K/pjfVeGrokeeKaf7LekvfXJyopXdE...
#
#                                       remember_token status twitter_url  \
# 0  sxoIOW7q3DhZC14fu2dIWK5ObWxoy4mN2Au49ZYfrFw8ha...      1        None
# ...

# %%
ls =  pd.read_json('listings.json')
ls
# Out:
#                                 comment  \
# 0  Export to JSON plugin for PHPMyAdmin
# 1                                   NaN
# 2                                   NaN
#
#                                                 data database      name  \
# 0                                                NaN      NaN       NaN
# 1                                                NaN      NaN    db_ktm
# 2  [{'id': '1', 'customer_id': '1', 'category_id'...   db_ktm  listings
#
#        type version
# 0    header   4.8.2
# 1  database     NaN
# 2     table     NaN

# %%
ls = pd.DataFrame(ls['data'][2])
ls
# Out:
#                                              address category_id  \
# 0  Jalan Margonda Raya No.353, Kemiri Muka, Depok...          23
#
#             created_at customer_id       details                       email  \
# 0  2018-11-20 07:31:18           1  Details Here  manishbasnyat182@gmail.com
#
#   fb_url google_url id        lat     ...        listing_name  \
# 0   None       None  1  -6.372777     ...      Seeded Listing
#
#                   lng                      main_image       phone     slug  \
# 0  106.83230389999994  3278_placeimg_640_480_tech.jpg  9989898989  news-24
#
#   status twitter_url           updated_at view_count website_url
# 0      1        None  2018-11-28 07:05:16         25        None
#
# [1 rows x 21 columns]

# %%
ls.columns
# Out:
# Index(['address', 'category_id', 'created_at', 'customer_id', 'details',
#        'email', 'fb_url', 'google_url', 'id', 'lat', 'like_count',
#        'listing_name', 'lng', 'main_image', 'phone', 'slug', 'status',
#        'twitter_url', 'updated_at', 'view_count', 'website_url'],
#       dtype='object')

# %%
ls.iloc[0][:]
# Out:
# address         Jalan Margonda Raya No.353, Kemiri Muka, Depok...
# category_id                                                    23
# created_at                                    2018-11-20 07:31:18
# customer_id                                                     1
# details                                              Details Here
# email                                  manishbasnyat182@gmail.com
# fb_url                                                       None
# google_url                                                   None
# id                                                              1
# lat                                                     -6.372777
# like_count                                                      1
# listing_name                                       Seeded Listing
# lng                                            106.83230389999994
# main_image                         3278_placeimg_640_480_tech.jpg
# ...
