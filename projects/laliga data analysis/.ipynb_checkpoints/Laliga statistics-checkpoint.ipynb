# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
laliga = pd.read_csv('FMEL_Dataset.csv')

# %%
laliga.head()
# Out:
#    id   season  division  round           localTeam         visitorTeam  \
# 0   1  1970-71         1      1  Atletico de Bilbao           Barcelona
# 1   2  1970-71         1      1          Las Palmas  Atletico de Madrid
# 2   3  1970-71         1      1         Real Madrid            Valencia
# 3   4  1970-71         1      1       Celta de Vigo   Sporting de Gijon
# 4   5  1970-71         1      1               Elche             Granada
#
#    localGoals  visitorGoals        date  timestamp
# 0           1             1  12/09/1970   21938400
# 1           1             1  12/09/1970   21938400
# 2           2             0  12/09/1970   21938400
# 3           2             0  13/09/1970   22024800
# 4           1             1  13/09/1970   22024800

# %%
laliga.isnull().sum()
# Out:
# id              0
# season          0
# division        0
# round           0
# localTeam       0
# visitorTeam     0
# localGoals      0
# visitorGoals    0
# date            0
# timestamp       0
# dtype: int64

# %%
laliga = laliga[laliga.division==1]

# %%
laliga.head()
# Out:
#    id   season  division  round           localTeam         visitorTeam  \
# 0   1  1970-71         1      1  Atletico de Bilbao           Barcelona
# 1   2  1970-71         1      1          Las Palmas  Atletico de Madrid
# 2   3  1970-71         1      1         Real Madrid            Valencia
# 3   4  1970-71         1      1       Celta de Vigo   Sporting de Gijon
# 4   5  1970-71         1      1               Elche             Granada
#
#    localGoals  visitorGoals        date  timestamp
# 0           1             1  12/09/1970   21938400
# 1           1             1  12/09/1970   21938400
# 2           2             0  12/09/1970   21938400
# 3           2             0  13/09/1970   22024800
# 4           1             1  13/09/1970   22024800

# %%
# la = (laliga['localGoals'] + laliga['visitorGoals']).grouby(laliga['localTeam'])

# %%
laliga['local_team_won']=laliga.apply(lambda row: 1 if row['localGoals']>row['visitorGoals'] else 0,axis=1)
laliga['visitor_team_won'] = laliga.apply(lambda row: 1 if row['localGoals'] < row['visitorGoals'] else 0, axis = 1)
laliga['draw'] = laliga.apply(lambda row: 1 if row['localGoals'] == row['visitorGoals'] else 0, axis =1)

# %%
laliga.head()
# Out:
#    id   season  division  round           localTeam         visitorTeam  \
# 0   1  1970-71         1      1  Atletico de Bilbao           Barcelona
# 1   2  1970-71         1      1          Las Palmas  Atletico de Madrid
# 2   3  1970-71         1      1         Real Madrid            Valencia
# 3   4  1970-71         1      1       Celta de Vigo   Sporting de Gijon
# 4   5  1970-71         1      1               Elche             Granada
#
#    localGoals  visitorGoals        date  timestamp  local_team_won  \
# 0           1             1  12/09/1970   21938400               0
# 1           1             1  12/09/1970   21938400               0
# 2           2             0  12/09/1970   21938400               1
# 3           2             0  13/09/1970   22024800               1
# 4           1             1  13/09/1970   22024800               0
#
#    visitor_team_won  draw
# 0                 0     1
# 1                 0     1
# 2                 0     0
# 3                 0     0
# 4                 0     1

# %%
dd = laliga.copy()
da = dd.groupby(['season','localTeam'])['local_team_won'].sum().reset_index().rename(columns={'localTeam':'club','local_team_won':'won'})
da.head(8)
# Out:
#     season                club  won
# 0  1970-71  Atletico de Bilbao   11
# 1  1970-71  Atletico de Madrid   13
# 2  1970-71           Barcelona   11
# 3  1970-71           CD Malaga    6
# 4  1970-71       Celta de Vigo   12
# 5  1970-71               Elche    4
# 6  1970-71             Espanol    7
# 7  1970-71             Granada    9

# %%
laliga.tail()
# Out:
#           id   season  division  round           localTeam    visitorTeam  \
# 36680  36681  2017-18         1     38          Villarreal    Real Madrid
# 36681  36682  2017-18         1     38  Atletico de Bilbao        Espanol
# 36682  36683  2017-18         1     38           Barcelona  Real Sociedad
# 36683  36684  2017-18         1     38            Valencia      Deportivo
# 36684  36685  2017-18         1     38  Atletico de Madrid          Eibar
#
#        localGoals  visitorGoals        date   timestamp  local_team_won  \
# 36680           2             2  19/05/2018  1526680800               0
# 36681           0             1  20/05/2018  1526767200               0
# 36682           1             0  20/05/2018  1526767200               1
# 36683           2             1  20/05/2018  1526767200               1
# 36684           2             2  20/05/2018  1526767200               0
#
#        visitor_team_won  draw
# 36680                 0     1
# 36681                 1     0
# 36682                 0     0
# 36683                 0     0
# 36684                 0     1

# %%
df=laliga.copy()

# %%
a=df.groupby(['season','localTeam'])['local_team_won'].sum().reset_index().rename(columns={'localTeam': 'club(local)','local_team_won': 'won'})
a.head()
# Out:
#     season         club(local)  won
# 0  1970-71  Atletico de Bilbao   11
# 1  1970-71  Atletico de Madrid   13
# 2  1970-71           Barcelona   11
# 3  1970-71           CD Malaga    6
# 4  1970-71       Celta de Vigo   12

# %%
b=df.groupby(['season','visitorTeam'])['visitor_team_won'].sum().reset_index().rename(columns={'visitorTeam': 'club(visitor)','visitor_team_won': 'won'})
b.head()
# Out:
#     season       club(visitor)  won
# 0  1970-71  Atletico de Bilbao    3
# 1  1970-71  Atletico de Madrid    4
# 2  1970-71           Barcelona    8
# 3  1970-71           CD Malaga    2
# 4  1970-71       Celta de Vigo    3

# %%
c=df.groupby(['season','localTeam'])['draw'].sum().reset_index().rename(columns={'localTeam': 'club(local)','draw': 'draw'})
c.head()
# Out:
#     season         club(local)  draw
# 0  1970-71  Atletico de Bilbao     3
# 1  1970-71  Atletico de Madrid     2
# 2  1970-71           Barcelona     1
# 3  1970-71           CD Malaga     6
# 4  1970-71       Celta de Vigo     3

# %%
d=df.groupby(['season','visitorTeam'])['draw'].sum().reset_index().rename(columns={'visitorTeam': 'club(visitor)','draw': 'draw'})
d.head()
# Out:
#     season       club(visitor)  draw
# 0  1970-71  Atletico de Bilbao     4
# 1  1970-71  Atletico de Madrid     6
# 2  1970-71           Barcelona     4
# 3  1970-71           CD Malaga     6
# 4  1970-71       Celta de Vigo     2

# %%
e=df.groupby(['season','localTeam'])['visitor_team_won'].sum().reset_index().rename(columns={'localTeam': 'club(local)','visitor_team_won': 'lost'})
e.head()
# Out:
#     season         club(local)  lost
# 0  1970-71  Atletico de Bilbao     1
# 1  1970-71  Atletico de Madrid     0
# 2  1970-71           Barcelona     3
# 3  1970-71           CD Malaga     3
# 4  1970-71       Celta de Vigo     0

# %%
f=df.groupby(['season','visitorTeam'])['local_team_won'].sum().reset_index().rename(columns={'visitorTeam': 'club(visitor)','local_team_won': 'lost'})
f.head()
# Out:
#     season       club(visitor)  lost
# 0  1970-71  Atletico de Bilbao     8
# 1  1970-71  Atletico de Madrid     5
# 2  1970-71           Barcelona     3
# 3  1970-71           CD Malaga     7
# 4  1970-71       Celta de Vigo    10

# %%
df.head()
# Out:
#    id   season  division  round           localTeam         visitorTeam  \
# 0   1  1970-71         1      1  Atletico de Bilbao           Barcelona
# 1   2  1970-71         1      1          Las Palmas  Atletico de Madrid
# 2   3  1970-71         1      1         Real Madrid            Valencia
# 3   4  1970-71         1      1       Celta de Vigo   Sporting de Gijon
# 4   5  1970-71         1      1               Elche             Granada
#
#    localGoals  visitorGoals        date  timestamp  local_team_won  \
# 0           1             1  12/09/1970   21938400               0
# 1           1             1  12/09/1970   21938400               0
# 2           2             0  12/09/1970   21938400               1
# 3           2             0  13/09/1970   22024800               1
# 4           1             1  13/09/1970   22024800               0
#
#    visitor_team_won  draw
# 0                 0     1
# 1                 0     1
# 2                 0     0
# 3                 0     0
# 4                 0     1

# %%
a = df.groupby(['season', 'localTeam'])['local_team_won'].sum().reset_index().rename(columns={'localTeam':'club','local_team_won':'won'})
b = df.groupby(['season', 'visitorTeam'])['visitor_team_won'].sum().reset_index().rename(columns={'visitorTeam':'club','visitor_team_won':'won'})
c = df.groupby(['season', 'localTeam'])['draw'].sum().reset_index().rename(columns={'localTeam':'club','draw':'draw'})
d = df.groupby(['season', 'visitorTeam'])['draw'].sum().reset_index().rename(columns={'visitorTeam':'club','draw':'draw'})
e = df.groupby(['season', 'localTeam'])['visitor_team_won'].sum().reset_index().rename(columns={'localTeam':'club','visitor_team_won':'lost'})
f = df.groupby(['season', 'visitorTeam'])['local_team_won'].sum().reset_index().rename(columns={'visitorTeam':'club','local_team_won':'lost'})

# %%
d.head()
# Out:
#     season                club  draw
# 0  1970-71  Atletico de Bilbao     4
# 1  1970-71  Atletico de Madrid     6
# 2  1970-71           Barcelona     4
# 3  1970-71           CD Malaga     6
# 4  1970-71       Celta de Vigo     2

# %%
pt = a.merge(b, on=['season','club']).merge(c, on=['season','club']).merge(d,on=['season','club']).merge(e, on=['season','club']).merge(f, on=['season','club'])
pt.head()
# Out:
#     season                club  won_x  won_y  draw_x  draw_y  lost_x  lost_y
# 0  1970-71  Atletico de Bilbao     11      3       3       4       1       8
# 1  1970-71  Atletico de Madrid     13      4       2       6       0       5
# 2  1970-71           Barcelona     11      8       1       4       3       3
# 3  1970-71           CD Malaga      6      2       6       6       3       7
# 4  1970-71       Celta de Vigo     12      3       3       2       0      10

# %%
a=df.groupby(['season','localTeam'])['local_team_won'].sum().reset_index().rename(columns={'localTeam': 'club','local_team_won': 'won'})
b=df.groupby(['season','visitorTeam'])['visitor_team_won'].sum().reset_index().rename(columns={'visitorTeam': 'club','visitor_team_won': 'won'})
c=df.groupby(['season','localTeam'])['draw'].sum().reset_index().rename(columns={'localTeam': 'club','draw': 'draw'})
d=df.groupby(['season','visitorTeam'])['draw'].sum().reset_index().rename(columns={'visitorTeam': 'club','draw': 'draw'})
e=df.groupby(['season','localTeam'])['visitor_team_won'].sum().reset_index().rename(columns={'localTeam': 'club','visitor_team_won': 'lost'})
f=df.groupby(['season','visitorTeam'])['local_team_won'].sum().reset_index().rename(columns={'visitorTeam': 'club','local_team_won': 'lost'})

# %%
point_table=a.merge(b,on=['season','club']).merge(c,on=['season','club']).merge(d,on=['season','club']).merge(e,on=['season','club']).merge(f,on=['season','club'])
point_table.tail(8)
#x represent home ground
#y represent away ground
# Out:
#       season           club  won_x  won_y  draw_x  draw_y  lost_x  lost_y
# 920  2017-18        Leganes      9      3       4       3       6      13
# 921  2017-18        Levante      7      4       6       7       6       8
# 922  2017-18         Malaga      4      1       3       2      12      16
# 923  2017-18    Real Madrid     12     10       4       6       3       3
# 924  2017-18  Real Sociedad     10      4       3       4       6      11
# 925  2017-18        Sevilla     11      6       5       2       3      11
# 926  2017-18       Valencia     13      9       3       4       3       6
# 927  2017-18     Villarreal     11      7       3       4       5       8

# %%
point_table[point_table['won_x']>10][point_table['season']=='2016-17']
# Out:
# C:\Users\Ramesh Pradhan\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#       season                club  won_x  won_y  draw_x  draw_y  lost_x  lost_y
# 889  2016-17  Atletico de Bilbao     13      6       4       2       2      11
# 890  2016-17  Atletico de Madrid     14      9       2       7       3       3
# 891  2016-17           Barcelona     15     13       3       3       1       3
# 902  2016-17         Real Madrid     14     15       4       2       1       2
# 904  2016-17             Sevilla     14      7       4       5       1       7
# 907  2016-17          Villarreal     11      8       4       6       4       5

# %%
point_table= point_table.rename(columns={'won_x':'home_win','won_y':'away_win','lost_x':'home_loss','lost_y':'away_loss'})

# %%
point_table.head()
# Out:
#     season                club  home_win  away_win  draw_x  draw_y  home_loss  \
# 0  1970-71  Atletico de Bilbao        11         3       3       4          1
# 1  1970-71  Atletico de Madrid        13         4       2       6          0
# 2  1970-71           Barcelona        11         8       1       4          3
# 3  1970-71           CD Malaga         6         2       6       6          3
# 4  1970-71       Celta de Vigo        12         3       3       2          0
#
#    away_loss
# 0          8
# 1          5
# 2          3
# 3          7
# 4         10

# %%
pt.head()
# Out:
#     season                club  won_x  won_y  draw_x  draw_y  lost_x  lost_y
# 0  1970-71  Atletico de Bilbao     11      3       3       4       1       8
# 1  1970-71  Atletico de Madrid     13      4       2       6       0       5
# 2  1970-71           Barcelona     11      8       1       4       3       3
# 3  1970-71           CD Malaga      6      2       6       6       3       7
# 4  1970-71       Celta de Vigo     12      3       3       2       0      10

# %%
pt = pt.rename(columns={'won_x':'home_win','won_y':'away_win','draw_x':'home_draw','draw_y':'away_draw','lost_x':'home_lost','lost_y':'away_lost'})
pt.head()
# Out:
#     season                club  home_win  away_win  home_draw  away_draw  \
# 0  1970-71  Atletico de Bilbao        11         3          3          4
# 1  1970-71  Atletico de Madrid        13         4          2          6
# 2  1970-71           Barcelona        11         8          1          4
# 3  1970-71           CD Malaga         6         2          6          6
# 4  1970-71       Celta de Vigo        12         3          3          2
#
#    home_lost  away_lost
# 0          1          8
# 1          0          5
# 2          3          3
# 3          3          7
# 4          0         10

# %%
pt['matches_won'] = pt.home_win + pt.away_win
pt['matches_lost'] = pt.home_lost + pt.away_lost
pt['matches_drawn'] = pt.home_draw + pt.away_draw
pt['total_matches'] = pt.matches_won + pt.matches_lost + pt.matches_drawn
pt.head()
# Out:
#     season                club  home_win  away_win  home_draw  away_draw  \
# 0  1970-71  Atletico de Bilbao        11         3          3          4
# 1  1970-71  Atletico de Madrid        13         4          2          6
# 2  1970-71           Barcelona        11         8          1          4
# 3  1970-71           CD Malaga         6         2          6          6
# 4  1970-71       Celta de Vigo        12         3          3          2
#
#    home_lost  away_lost  matches_won  matches_lost  matches_drawn  \
# 0          1          8           14             9              7
# 1          0          5           17             5              8
# 2          3          3           19             6              5
# 3          3          7            8            10             12
# 4          0         10           15            10              5
#
#    total_matches
# 0             30
# 1             30
# 2             30
# 3             30
# 4             30

# %%
pt['point'] = pt.matches_won * 3 + pt.matches_drawn * 1
pt.head()
# Out:
#     season                club  home_win  away_win  home_draw  away_draw  \
# 0  1970-71  Atletico de Bilbao        11         3          3          4
# 1  1970-71  Atletico de Madrid        13         4          2          6
# 2  1970-71           Barcelona        11         8          1          4
# 3  1970-71           CD Malaga         6         2          6          6
# 4  1970-71       Celta de Vigo        12         3          3          2
#
#    home_lost  away_lost  matches_won  matches_lost  matches_drawn  \
# 0          1          8           14             9              7
# 1          0          5           17             5              8
# 2          3          3           19             6              5
# 3          3          7            8            10             12
# 4          0         10           15            10              5
#
#    total_matches  point
# 0             30     49
# 1             30     59
# 2             30     62
# 3             30     36
# 4             30     50

# %%
point_table['matches_won']=point_table.home_win+point_table.away_win
point_table['matches_lost']=point_table.home_loss+point_table.away_loss
point_table['matches_drawn']=point_table.draw_x+point_table.draw_y
point_table=point_table.drop(['draw_x','draw_y'],axis=1)
point_table['total_matches']=point_table.matches_won+point_table.matches_lost+point_table.matches_drawn

# %%
point_table.head()
# Out:
#     season                club  home_win  away_win  home_loss  away_loss  \
# 0  1970-71  Atletico de Bilbao        11         3          1          8
# 1  1970-71  Atletico de Madrid        13         4          0          5
# 2  1970-71           Barcelona        11         8          3          3
# 3  1970-71           CD Malaga         6         2          3          7
# 4  1970-71       Celta de Vigo        12         3          0         10
#
#    matches_won  matches_lost  matches_drawn  total_matches
# 0           14             9              7             30
# 1           17             5              8             30
# 2           19             6              5             30
# 3            8            10             12             30
# 4           15            10              5             30

# %%
point_table['points']=(point_table.matches_won*3)+(point_table.matches_drawn*1)
point_table.head()
# Out:
#     season                club  home_win  away_win  home_loss  away_loss  \
# 0  1970-71  Atletico de Bilbao        11         3          1          8
# 1  1970-71  Atletico de Madrid        13         4          0          5
# 2  1970-71           Barcelona        11         8          3          3
# 3  1970-71           CD Malaga         6         2          3          7
# 4  1970-71       Celta de Vigo        12         3          0         10
#
#    matches_won  matches_lost  matches_drawn  total_matches  points
# 0           14             9              7             30      49
# 1           17             5              8             30      59
# 2           19             6              5             30      62
# 3            8            10             12             30      36
# 4           15            10              5             30      50

# %%
df.head()
# Out:
#    id   season  division  round           localTeam         visitorTeam  \
# 0   1  1970-71         1      1  Atletico de Bilbao           Barcelona
# 1   2  1970-71         1      1          Las Palmas  Atletico de Madrid
# 2   3  1970-71         1      1         Real Madrid            Valencia
# 3   4  1970-71         1      1       Celta de Vigo   Sporting de Gijon
# 4   5  1970-71         1      1               Elche             Granada
#
#    localGoals  visitorGoals        date  timestamp  local_team_won  \
# 0           1             1  12/09/1970   21938400               0
# 1           1             1  12/09/1970   21938400               0
# 2           2             0  12/09/1970   21938400               1
# 3           2             0  13/09/1970   22024800               1
# 4           1             1  13/09/1970   22024800               0
#
#    visitor_team_won  draw
# 0                 0     1
# 1                 0     1
# 2                 0     0
# 3                 0     0
# 4                 0     1

# %%
g=df.groupby(['season','localTeam'])['localGoals'].sum().reset_index().rename(columns={'localTeam': 'club','localGoals': 'home_goals'})
h=df.groupby(['season','visitorTeam'])['visitorGoals'].sum().reset_index().rename(columns={'visitorTeam': 'club','visitorGoals': 'away_goals'})
i=df.groupby(['season','localTeam'])['visitorGoals'].sum().reset_index().rename(columns={'localTeam': 'club','visitorGoals': 'goals_conceded'})
j=df.groupby(['season','visitorTeam'])['localGoals'].sum().reset_index().rename(columns={'visitorTeam': 'club','localGoals': 'goals_conceded'})

# %%
point_table=point_table.merge(g,on=['season','club']).merge(h,on=['season','club']).merge(i,on=['season','club']).merge(j,on=['season','club'])
point_table.head()
# Out:
#     season                club  home_win  away_win  home_loss  away_loss  \
# 0  1970-71  Atletico de Bilbao        11         3          1          8
# 1  1970-71  Atletico de Madrid        13         4          0          5
# 2  1970-71           Barcelona        11         8          3          3
# 3  1970-71           CD Malaga         6         2          3          7
# 4  1970-71       Celta de Vigo        12         3          0         10
#
#    matches_won  matches_lost  matches_drawn  total_matches  points  \
# 0           14             9              7             30      49
# 1           17             5              8             30      59
# 2           19             6              5             30      62
# 3            8            10             12             30      36
# 4           15            10              5             30      50
#
#    home_goals  away_goals  goals_conceded_x  goals_conceded_y
# 0          23          17                 4                27
# 1          38          13                 9                11
# 2          32          18                11                11
# 3          14          13                10                22
# 4          23          14                 4                28

# %%
point_table['goals_scored']=point_table.home_goals+point_table.away_goals
point_table['goals_conceded']=point_table.goals_conceded_x+point_table.goals_conceded_y
point_table['goal_difference']=point_table.goals_scored-point_table.goals_conceded
point_table= point_table.drop(['goals_conceded_x','goals_conceded_y'],axis=1)

# %%
point_table.head()
# Out:
#     season                club  home_win  away_win  home_loss  away_loss  \
# 0  1970-71  Atletico de Bilbao        11         3          1          8
# 1  1970-71  Atletico de Madrid        13         4          0          5
# 2  1970-71           Barcelona        11         8          3          3
# 3  1970-71           CD Malaga         6         2          3          7
# 4  1970-71       Celta de Vigo        12         3          0         10
#
#    matches_won  matches_lost  matches_drawn  total_matches  points  \
# 0           14             9              7             30      49
# 1           17             5              8             30      59
# 2           19             6              5             30      62
# 3            8            10             12             30      36
# 4           15            10              5             30      50
#
#    home_goals  away_goals  goals_scored  goals_conceded  goal_difference
# 0          23          17            40              31                9
# 1          38          13            51              20               31
# 2          32          18            50              22               28
# 3          14          13            27              32               -5
# 4          23          14            37              32                5

# %%
point_table= point_table.sort_values(by=['season','points','goal_difference']).reset_index().drop('index',axis=1)
point_table.head(10)
# Out:
#     season               club  home_win  away_win  home_loss  away_loss  \
# 0  1970-71           Zaragoza         3         0          5         13
# 1  1970-71              Elche         4         0          5         11
# 2  1970-71         Las Palmas         5         0          3         12
# 3  1970-71           Sabadell         8         0          3         14
# 4  1970-71            Espanol         7         1          4          9
# 5  1970-71  Sporting de Gijon         9         1          4         11
# 6  1970-71          CD Malaga         6         2          3          7
# 7  1970-71            Granada         9         1          1         11
# 8  1970-71      Real Sociedad         9         1          3          8
# 9  1970-71            Sevilla        11         2          1         10
#
#    matches_won  matches_lost  matches_drawn  total_matches  points  \
# 0            3            18              9             30      18
# 1            4            16             10             30      22
# 2            5            15             10             30      25
# 3            8            17              5             30      29
# 4            8            13              9             30      33
# 5           10            15              5             30      35
# 6            8            10             12             30      36
# 7           10            12              8             30      38
# 8           10            11              9             30      39
# 9           13            11              6             30      45
#
#    home_goals  away_goals  goals_scored  goals_conceded  goal_difference
# 0          14           8            22              54              -32
# 1          17           8            25              46              -21
# 2          25           8            33              42               -9
# 3          19           9            28              49              -21
# 4          13           5            18              25               -7
# 5          29           6            35              44               -9
# 6          14          13            27              32               -5
# 7          24           9            33              34               -1
# 8          18           5            23              27               -4
# 9          26           8            34              42               -8

# %%
point_table.tail(n=12).sort_values('points',ascending=False)
# Out:
#       season                club  home_win  away_win  home_loss  away_loss  \
# 927  2017-18           Barcelona        16        12          0          1
# 926  2017-18  Atletico de Madrid        12        11          1          4
# 925  2017-18         Real Madrid        12        10          3          3
# 924  2017-18            Valencia        13         9          3          6
# 923  2017-18          Villarreal        11         7          5          8
# 922  2017-18               Betis        10         8          5          9
# 921  2017-18             Sevilla        11         6          3         11
# 920  2017-18              Getafe         9         6          6          7
# 918  2017-18              Girona         8         6          8          7
# 919  2017-18               Eibar         8         6          7          8
# 916  2017-18       Celta de Vigo         8         5          3         12
# 917  2017-18       Real Sociedad        10         4          6         11
#
#      matches_won  matches_lost  matches_drawn  total_matches  points  \
# 927           28             1              9             38      93
# 926           23             5             10             38      79
# 925           22             6             10             38      76
# 924           22             9              7             38      73
# 923           18            13              7             38      61
# 922           18            14              6             38      60
# 921           17            14              7             38      58
# 920           15            13             10             38      55
# 918           14            15              9             38      51
# 919           14            15              9             38      51
# 916           13            15             10             38      49
# 917           14            17              7             38      49
#
#      home_goals  away_goals  goals_scored  goals_conceded  goal_difference
# 927          53          46            99              29               70
# 926          30          28            58              22               36
# 925          54          40            94              44               50
# 924          36          29            65              38               27
# 923          35          22            57              50                7
# 922          35          25            60              61               -1
# 921          31          18            49              58               -9
# 920          26          16            42              33                9
# 918          26          24            50              59               -9
# 919          26          18            44              50               -6
# 916          34          25            59              60               -1
# 917          47          19            66              59                7

# %%
df=point_table.copy()

# %%
df.head()
# Out:
#     season        club  home_win  away_win  home_loss  away_loss  matches_won  \
# 0  1970-71    Zaragoza         3         0          5         13            3
# 1  1970-71       Elche         4         0          5         11            4
# 2  1970-71  Las Palmas         5         0          3         12            5
# 3  1970-71    Sabadell         8         0          3         14            8
# 4  1970-71     Espanol         7         1          4          9            8
#
#    matches_lost  matches_drawn  total_matches  points  home_goals  away_goals  \
# 0            18              9             30      18          14           8
# 1            16             10             30      22          17           8
# 2            15             10             30      25          25           8
# 3            17              5             30      29          19           9
# 4            13              9             30      33          13           5
#
#    goals_scored  goals_conceded  goal_difference
# 0            22              54              -32
# 1            25              46              -21
# 2            33              42               -9
# 3            28              49              -21
# 4            18              25               -7

# %%
champs=df[df.groupby(['season'])['points'].transform(max)==df.points].reset_index()
champs.tail(15)
# Out:
#     index   season                club  home_win  away_win  home_loss  \
# 34    667  2004-05           Barcelona        14        11          1
# 35    687  2005-06           Barcelona        15        10          1
# 36    706  2006-07         Real Madrid        12        11          3
# 37    707  2006-07           Barcelona        14         8          0
# 38    727  2007-08         Real Madrid        17        10          2
# 39    747  2008-09           Barcelona        14        13          2
# 40    767  2009-10           Barcelona        18        13          0
# 41    787  2010-11           Barcelona        16        14          1
# 42    807  2011-12         Real Madrid        16        16          1
# 43    827  2012-13           Barcelona        18        14          0
# 44    847  2013-14  Atletico de Madrid        15        13          0
# 45    867  2014-15           Barcelona        16        14          2
# 46    887  2015-16           Barcelona        16        13          2
# 47    907  2016-17         Real Madrid        14        15          1
# 48    927  2017-18           Barcelona        16        12          0
#
#     away_loss  matches_won  matches_lost  matches_drawn  total_matches  \
# 34          3           25             4              9             38
# 35          5           25             6              7             38
# 36          5           23             8              7             38
# 37          6           22             6             10             38
# 38          5           27             7              4             38
# 39          3           27             5              6             38
# 40          1           31             1              6             38
# 41          1           30             2              6             38
# 42          1           32             2              4             38
# 43          2           32             2              4             38
# 44          4           28             4              6             38
# 45          2           30             4              4             38
# 46          3           29             5              4             38
# 47          2           29             3              6             38
# 48          1           28             1              9             38
#
#     points  home_goals  away_goals  goals_scored  goals_conceded  \
# 34      84          40          33            73              29
# 35      82          45          35            80              35
# 36      76          32          34            66              40
# 37      76          41          37            78              33
# 38      85          53          31            84              36
# 39      87          61          44           105              35
# 40      99          57          41            98              24
# 41      96          46          49            95              21
# 42     100          70          51           121              32
# 43     100          63          52           115              40
# 44      90          49          28            77              26
# 45      94          64          46           110              21
# 46      91          67          45           112              29
# 47      93          48          58           106              41
# 48      93          53          46            99              29
#
#     goal_difference
# 34               44
# 35               45
# 36               26
# 37               45
# 38               48
# 39               70
# 40               74
# 41               74
# 42               89
# 43               75
# 44               51
# 45               89
# 46               83
# 47               65
# 48               70

# %%
champs=champs.drop(champs.index[[37]])
champs.tail(20).sort_values('season',ascending=False)
# Out:
#     index   season                club  home_win  away_win  home_loss  \
# 48    927  2017-18           Barcelona        16        12          0
# 47    907  2016-17         Real Madrid        14        15          1
# 46    887  2015-16           Barcelona        16        13          2
# 45    867  2014-15           Barcelona        16        14          2
# 44    847  2013-14  Atletico de Madrid        15        13          0
# 43    827  2012-13           Barcelona        18        14          0
# 42    807  2011-12         Real Madrid        16        16          1
# 41    787  2010-11           Barcelona        16        14          1
# 40    767  2009-10           Barcelona        18        13          0
# 39    747  2008-09           Barcelona        14        13          2
# 38    727  2007-08         Real Madrid        17        10          2
# 36    706  2006-07         Real Madrid        12        11          3
# 35    687  2005-06           Barcelona        15        10          1
# 34    667  2004-05           Barcelona        14        11          1
# 33    647  2003-04            Valencia        12        11          4
# 32    627  2002-03         Real Madrid        13         9          1
# 31    607  2001-02            Valencia        14         7          1
# 30    587  2000-01         Real Madrid        15         9          1
# 29    567  1999-00           Deportivo        16         5          2
# 28    547  1998-99           Barcelona        13        11          3
#
#     away_loss  matches_won  matches_lost  matches_drawn  total_matches  \
# 48          1           28             1              9             38
# 47          2           29             3              6             38
# 46          3           29             5              4             38
# 45          2           30             4              4             38
# 44          4           28             4              6             38
# 43          2           32             2              4             38
# 42          1           32             2              4             38
# 41          1           30             2              6             38
# 40          1           31             1              6             38
# 39          3           27             5              6             38
# 38          5           27             7              4             38
# 36          5           23             8              7             38
# 35          5           25             6              7             38
# 34          3           25             4              9             38
# 33          3           23             7              8             38
# 32          3           22             4             12             38
# 31          4           21             5             12             38
# 30          5           24             6              8             38
# 29          9           21            11              6             38
# 28          4           24             7              7             38
#
#     points  home_goals  away_goals  goals_scored  goals_conceded  \
# 48      93          53          46            99              29
# 47      93          48          58           106              41
# 46      91          67          45           112              29
# 45      94          64          46           110              21
# 44      90          49          28            77              26
# 43     100          63          52           115              40
# 42     100          70          51           121              32
# 41      96          46          49            95              21
# 40      99          57          41            98              24
# 39      87          61          44           105              35
# 38      85          53          31            84              36
# 36      76          32          34            66              40
# 35      82          45          35            80              35
# 34      84          40          33            73              29
# 33      77          38          33            71              27
# 32      78          52          34            86              42
# 31      75          28          23            51              27
# 30      80          53          28            81              40
# 29      69          47          19            66              44
# 28      79          52          35            87              43
#
#     goal_difference
# 48               70
# 47               65
# 46               83
# 45               89
# 44               51
# 43               75
# 42               89
# 41               74
# 40               74
# 39               70
# 38               48
# 36               26
# 35               45
# 34               44
# 33               44
# 32               44
# 31               24
# 30               41
# 29               22
# 28               44

# %%
champs.club.value_counts().reset_index().rename(columns={'index':'club', 'club':'trophies'})
# Out:
#                  club  trophies
# 0         Real Madrid        21
# 1           Barcelona        19
# 2  Atletico de Madrid         4
# 3            Valencia         2
# 4  Atletico de Bilbao         1
# 5           Deportivo         1
# 6       Real Sociedad         1
