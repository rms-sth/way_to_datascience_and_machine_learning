# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
df = pd.read_json('db_recommend.json')
df
# Out:
#                                 comment  \
# 0  Export to JSON plugin for PHPMyAdmin
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
#
#                                                 data      database  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2  [{'uid': '8', 'firstname': 'ramesh', 'middlena...  db_recommend
# 3  [{'bid': '86', 'uid': '14', 'pid': '1', 'ratin...  db_recommend
# 4  [{'cid': '1', 'cname': 'Instrument Calibration...  db_recommend
# 5  [{'pid': '1', 'pname': 'dell inspiron 57 i3 2g...  db_recommend
# 6  [{'uid': '1', 'firstname': 'ramesh', 'middlena...  db_recommend
#
#                  name      type version
# 0                 NaN    header   4.8.2
# ...

# %%
df['data'].dropna(inplace=True)

# %%
df['data']
# Out:
# 2    [{'uid': '8', 'firstname': 'ramesh', 'middlena...
# 3    [{'bid': '86', 'uid': '14', 'pid': '1', 'ratin...
# 4    [{'cid': '1', 'cname': 'Instrument Calibration...
# 5    [{'pid': '1', 'pname': 'dell inspiron 57 i3 2g...
# 6    [{'uid': '1', 'firstname': 'ramesh', 'middlena...
# Name: data, dtype: object

# %%
pd.DataFrame(df['data'][2])
# Out:
#                         email firstname lastname middlename password uid  \
# 0            ramesh@gmail.com    ramesh  pradhan       None   ramesh   8
# 1            bhuwan@gmail.com    bhuwan  pandeya        raj   bhuwan   9
# 2      subodhthakur@gmail.com    subodh   thakur              subodh  10
# 3  bijeshjungbasent@gmail.com    bijesh   basnet       jung   bijesh  11
# 4             human@gmail.com     human    being       None    human  12
# 5            normal@gmail.com    normal   normal       None   normal  13
# 6             admin@gmail.com     admin    admin               admin  14
#
#           username
# 0           ramesh
# 1           bhuwan
# 2     subodhthakur
# 3  bijeshjungbasne
# 4            human
# 5           normal
# 6            admin

# %%
pd.DataFrame(df['data'][3])
# Out:
#   bid pid rating uid
# 0  86   1      5  14
# 1  87   2      4  14
# 2  88   3      1  14
# 3  89   1      5  15
# 4  90   2      4  15
# 5  91   3      1  15
# 6  92   5      5  15

# %%
pd.DataFrame(df['data'][4])
# Out:
#      cid                                              cname
# 0      1                Instrument Calibration & Adjustment
# 1      2               Computer PCI Cards, Cables & Modules
# 2      3           Light Bulb, Lamp & Lighting Fixtures\r\n
# 3      4                 Electric Motors and Components\r\n
# 4      5                     Headphones and Microphones\r\n
# 5      6              Electrical and Electronic Gadgets\r\n
# 6      7           Instrumentation & Control Equipments\r\n
# 7      8           Optical, Laser Instruments & Devices\r\n
# 8      9           Heater, Thermostat & Heating Devices\r\n
# 9     10           Fuses, Circuit Breakers & Components\r\n
# 10    11                Instrument Calibration & Adjustment
# 11    12               Computer PCI Cards, Cables & Modules
# 12    13           Light Bulb, Lamp & Lighting Fixtures\r\n
# 13    14                 Electric Motors and Components\r\n
# 14    17           Instrumentation & Control Equipments\r\n
# ...
