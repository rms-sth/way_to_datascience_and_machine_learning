# %%
import pandas as pd

# %%
df_red = pd.read_csv('winequality-red.csv', sep=';')
df_white = pd.read_csv('winequality-white.csv', sep=';')

# %%
df_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df_white.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
df_red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df_red.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df_white.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df_white[df_white['quality']>6].head()
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 13            6.6              0.16         0.40             1.5      0.044
# 15            6.6              0.17         0.38             1.5      0.032
# 17            6.2              0.66         0.48             1.2      0.029
# 20            6.2              0.66         0.48             1.2      0.029
# 21            6.4              0.31         0.38             2.9      0.038
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 13                 48.0                 143.0   0.9912  3.54       0.52
# 15                 28.0                 112.0   0.9914  3.25       0.55
# 17                 29.0                  75.0   0.9892  3.33       0.39
# 20                 29.0                  75.0   0.9892  3.33       0.39
# 21                 19.0                 102.0   0.9912  3.17       0.35
#
#     alcohol  quality
# 13     12.4        7
# 15     11.4        7
# ...

# %%
df_white[df_white['quality']<6].head()
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 10            8.1              0.27         0.41            1.45      0.033
# 11            8.6              0.23         0.40            4.20      0.035
# 12            7.9              0.18         0.37            1.20      0.040
# 14            8.3              0.42         0.62           19.25      0.040
# 19            6.5              0.31         0.14            7.50      0.044
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 10                 11.0                  63.0   0.9908  2.99       0.56
# 11                 17.0                 109.0   0.9947  3.14       0.53
# 12                 16.0                  75.0   0.9920  3.18       0.63
# 14                 41.0                 172.0   1.0002  2.98       0.67
# 19                 34.0                 133.0   0.9955  3.22       0.50
#
#     alcohol  quality
# 10     12.0        5
# 11      9.7        5
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df_white['volatile acidity'],df_white['citric acid'], df_white['chlorides'],df_white['sulphates'])

# %%
df_white.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
plt.plot(df_white['volatile acidity'],df_white['citric acid'], df_white['chlorides'],df_white['sulphates'])

# %%
df_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
group = df_white.groupby('quality')

# %%
group.count()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                   20                20           20              20
# 4                  163               163          163             163
# 5                 1457              1457         1457            1457
# 6                 2198              2198         2198            2198
# 7                  880               880          880             880
# 8                  175               175          175             175
# 9                    5                 5            5               5
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# 3               20                   20                    20       20    20
# 4              163                  163                   163      163   163
# 5             1457                 1457                  1457     1457  1457
# 6             2198                 2198                  2198     2198  2198
# ...

# %%
group.mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             7.600000          0.333250     0.336000        6.392500
# 4             7.129448          0.381227     0.304233        4.628221
# 5             6.933974          0.302011     0.337653        7.334969
# 6             6.837671          0.260564     0.338025        6.441606
# 7             6.734716          0.262767     0.325625        5.186477
# 8             6.657143          0.277400     0.326514        5.671429
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.054300            53.325000            170.600000  0.994884
# 4         0.050098            23.358896            125.279141  0.994277
# 5         0.051546            36.432052            150.904598  0.995263
# 6         0.045217            35.650591            137.047316  0.993961
# ...

# %%
group.max()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                 11.8             0.640         0.47           16.20
# 4                 10.2             1.100         0.88           17.55
# 5                 10.3             0.905         1.00           23.50
# 6                 14.2             0.965         1.66           65.80
# 7                  9.2             0.760         0.74           19.25
# 8                  8.2             0.660         0.74           14.80
# 9                  9.1             0.360         0.49           10.60
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# 3            0.244                289.0                 440.0  1.00010  3.55
# 4            0.290                138.5                 272.0  1.00040  3.72
# 5            0.346                131.0                 344.0  1.00241  3.79
# 6            0.255                112.0                 294.0  1.03898  3.81
# ...

# %%
group.min()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                  4.2              0.17         0.21             0.7
# 4                  4.8              0.11         0.00             0.7
# 5                  4.5              0.10         0.00             0.6
# 6                  3.8              0.08         0.00             0.7
# 7                  4.2              0.08         0.01             0.9
# 8                  3.9              0.12         0.04             0.8
# 9                  6.6              0.24         0.29             1.6
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# 3            0.022                  5.0                  19.0  0.99110  2.87
# 4            0.013                  3.0                  10.0  0.98920  2.83
# 5            0.009                  2.0                   9.0  0.98722  2.79
# 6            0.015                  3.0                  18.0  0.98758  2.72
# ...

# %%
group.describe()
# Out:
#         alcohol                                                        \
#           count       mean       std   min    25%    50%    75%   max
# quality
# 3          20.0  10.345000  1.224089   8.0   9.55  10.45  11.00  12.6
# 4         163.0  10.152454  1.003217   8.4   9.40  10.10  10.75  13.5
# 5        1457.0   9.808840  0.847065   8.0   9.20   9.50  10.30  13.6
# 6        2198.0  10.575372  1.147776   8.5   9.60  10.50  11.40  14.0
# 7         880.0  11.367936  1.246536   8.6  10.60  11.40  12.30  14.2
# 8         175.0  11.636000  1.280138   8.5  11.00  12.00  12.60  14.0
# 9           5.0  12.180000  1.013410  10.4  12.40  12.50  12.70  12.9
#
#         chlorides            ...   total sulfur dioxide         \
#             count      mean  ...                    75%    max
# quality                      ...
# 3            20.0  0.054300  ...                 210.00  440.0
# 4           163.0  0.050098  ...                 171.50  272.0
# ...

# %%
group.describe().transpose()
# Out:
# quality                              3           4            5            6  \
# alcohol              count   20.000000  163.000000  1457.000000  2198.000000
#                      mean    10.345000   10.152454     9.808840    10.575372
#                      std      1.224089    1.003217     0.847065     1.147776
#                      min      8.000000    8.400000     8.000000     8.500000
#                      25%      9.550000    9.400000     9.200000     9.600000
#                      50%     10.450000   10.100000     9.500000    10.500000
#                      75%     11.000000   10.750000    10.300000    11.400000
#                      max     12.600000   13.500000    13.600000    14.000000
# chlorides            count   20.000000  163.000000  1457.000000  2198.000000
#                      mean     0.054300    0.050098     0.051546     0.045217
#                      std      0.046468    0.025888     0.026496     0.020453
# ...

# %%
group.describe().transpose().loc['alcohol']
# Out:
# quality          3           4            5            6           7  \
# count    20.000000  163.000000  1457.000000  2198.000000  880.000000
# mean     10.345000   10.152454     9.808840    10.575372   11.367936
# std       1.224089    1.003217     0.847065     1.147776    1.246536
# min       8.000000    8.400000     8.000000     8.500000    8.600000
# 25%       9.550000    9.400000     9.200000     9.600000   10.600000
# 50%      10.450000   10.100000     9.500000    10.500000   11.400000
# 75%      11.000000   10.750000    10.300000    11.400000   12.300000
# max      12.600000   13.500000    13.600000    14.000000   14.200000
#
# quality           8         9
# count    175.000000   5.00000
# mean      11.636000  12.18000
# std        1.280138   1.01341
# min        8.500000  10.40000
# 25%       11.000000  12.40000
# 50%       12.000000  12.50000
# 75%       12.600000  12.70000
# max       14.000000  12.90000

# %%
group.describe()['chlorides']
# Out:
#           count      mean       std    min      25%    50%    75%    max
# quality
# 3          20.0  0.054300  0.046468  0.022  0.03625  0.041  0.054  0.244
# 4         163.0  0.050098  0.025888  0.013  0.03800  0.046  0.054  0.290
# 5        1457.0  0.051546  0.026496  0.009  0.04000  0.047  0.053  0.346
# 6        2198.0  0.045217  0.020453  0.015  0.03600  0.043  0.049  0.255
# 7         880.0  0.038191  0.010697  0.012  0.03100  0.037  0.044  0.135
# 8         175.0  0.038314  0.013164  0.014  0.03000  0.036  0.044  0.121
# 9           5.0  0.027400  0.007436  0.018  0.02100  0.031  0.032  0.035
