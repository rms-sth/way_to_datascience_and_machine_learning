# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv('/home/vins/Documents/jupyter_scripts/dataset/dataset_Facebook.csv',sep=';')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# 7              139441   Photo         3          12             7          9
# 8              139441  Status         2          12             7          3
# 9              139441   Photo         3          12             6         10
# 10             139441  Status         2          12             5         10
# ...

# %%
col_list=list(df.columns)

# %%
col_list
# Out:
# ['Page total likes',
#  'Type',
#  'Category',
#  'Post Month',
#  'Post Weekday',
#  'Post Hour',
#  'Paid',
#  'Lifetime Post Total Reach',
#  'Lifetime Post Total Impressions',
#  'Lifetime Engaged Users',
#  'Lifetime Post Consumers',
#  'Lifetime Post Consumptions',
#  'Lifetime Post Impressions by people who have liked your Page',
#  'Lifetime Post reach by people who like your Page',
#  'Lifetime People who have liked your Page and engaged with your post',
#  'comment',
#  'like',
#  'share',
#  'Total Interactions']

# %%
for i in col_list:
    print i
# Out:
# Page total likes
# Type
# Category
# Post Month
# Post Weekday
# Post Hour
# Paid
# Lifetime Post Total Reach
# Lifetime Post Total Impressions
# Lifetime Engaged Users
# Lifetime Post Consumers
# Lifetime Post Consumptions
# Lifetime Post Impressions by people who have liked your Page
# Lifetime Post reach by people who like your Page
# Lifetime People who have liked your Page and engaged with your post
# comment
# like
# share
# Total Interactions

# %%
df.head(5)
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.tail(5)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.dtypes
# Out:
# Page total likes                                                         int64
# Type                                                                    object
# Category                                                                 int64
# Post Month                                                               int64
# Post Weekday                                                             int64
# Post Hour                                                                int64
# Paid                                                                   float64
# Lifetime Post Total Reach                                                int64
# Lifetime Post Total Impressions                                          int64
# Lifetime Engaged Users                                                   int64
# Lifetime Post Consumers                                                  int64
# Lifetime Post Consumptions                                               int64
# ...

# %%
df.tail
# Out:
# <bound method DataFrame.tail of      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# 7              139441   Photo         3          12             7          9
# 8              139441  Status         2          12             7          3
# 9              139441   Photo         3          12             6         10
# 10             139441  Status         2          12             5         10
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
df.Type
# Out:
# 0       Photo
# 1      Status
# 2       Photo
# 3       Photo
# 4       Photo
# 5      Status
# 6       Photo
# 7       Photo
# 8      Status
# 9       Photo
# 10     Status
# 11      Photo
# 12      Photo
# 13      Photo
# 14      Photo
# 15     Status
# 16      Photo
# 17      Photo
# 18     Status
# 19      Photo
# 20      Photo
# 21      Photo
# 22       Link
# 23      Photo
# 24     Status
# 25     Status
# 26     Status
# 27      Photo
# 28      Photo
# 29      Video
#         ...
# 470      Link
# 471     Photo
# 472     Photo
# 473     Photo
# 474     Photo
# 475     Photo
# 476     Photo
# 477      Link
# 478     Photo
# 479     Photo
# 480     Photo
# 481      Link
# 482     Photo
# 483     Photo
# 484     Photo
# 485      Link
# 486     Photo
# 487     Photo
# 488     Photo
# 489     Photo
# 490     Photo
# 491     Photo
# 492      Link
# 493     Photo
# 494     Photo
# 495     Photo
# 496     Photo
# 497     Photo
# 498     Photo
# 499     Photo
# ...

# %%
df.groupby('Type').sum()
# Out:
#         Page total likes  Category  Post Month  Post Weekday  Post Hour  \
# Type
# Link             2559990        25         145            94        126
# Photo           52122877       817        2899          1750       3407
# Status           5969117        91         408           206        326
# Video             945104         7          67            25         61
#
#          Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# Type
# Link      6.0                     407981                           631960
# Photo   119.0                    5596709                         12351656
# Status   10.0                     588550                          1091001
# Video     4.0                     358440                           718357
#
#         Lifetime Engaged Users  Lifetime Post Consumers  \
# Type
# Link                      7542                     6439
# Photo                   348871                   294124
# ...

# %%
df.groupby('Type').count()
# Out:
#         Page total likes  Category  Post Month  Post Weekday  Post Hour  Paid  \
# Type
# Link                  22        22          22            22         22    22
# Photo                426       426         426           426        426   425
# Status                45        45          45            45         45    45
# Video                  7         7           7             7          7     7
#
#         Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# Type
# Link                           22                               22
# Photo                         426                              426
# Status                         45                               45
# Video                           7                                7
#
#         Lifetime Engaged Users  Lifetime Post Consumers  \
# Type
# Link                        22                       22
# Photo                      426                      426
# ...

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# 7              139441   Photo         3          12             7          9
# 8              139441  Status         2          12             7          3
# 9              139441   Photo         3          12             6         10
# 10             139441  Status         2          12             5         10
# ...

# %%
col_list
# Out:
# ['Page total likes',
#  'Type',
#  'Category',
#  'Post Month',
#  'Post Weekday',
#  'Post Hour',
#  'Paid',
#  'Lifetime Post Total Reach',
#  'Lifetime Post Total Impressions',
#  'Lifetime Engaged Users',
#  'Lifetime Post Consumers',
#  'Lifetime Post Consumptions',
#  'Lifetime Post Impressions by people who have liked your Page',
#  'Lifetime Post reach by people who like your Page',
#  'Lifetime People who have liked your Page and engaged with your post',
#  'comment',
#  'like',
#  'share',
#  'Total Interactions']

# %%
df[df['Lifetime Post Total Impressions']>7000]
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# 7              139441   Photo         3          12             7          9
# 8              139441  Status         2          12             7          3
# 9              139441   Photo         3          12             6         10
# 10             139441  Status         2          12             5         10
# 14             138414   Photo         2          12             4          5
# 15             138414  Status         2          12             3         10
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ebb47207bc32> in <module>()
# ----> 1 df.max()
#
# NameError: name 'df' is not defined
